# %%
# tcs = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/trans/202031.parquet")
# tcs = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/prep/operations/build/{i}.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["card","hhld","card_master","hhld_master","product","product_master","store","store_master"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/prep/operations/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/prep/operations/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
        
        
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# ...

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tables = ["offer_type","reward_202306"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/crm/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/crm/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["saleslink"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
        
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["pro_ean"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/build/pro_ean_202306.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/pro_ean_202305.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/build/nielsen_prod_chars_202306.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/nielsen_prod_chars_202305.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/build/pro_chars_202306.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/pro_chars_202305.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
               
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["bas_","bas_ex_","itm_","itm_ex_"]
def check(aa,bb):
  for j in tables:
    for i in range(aa,bb+1):
        tcs[f'{str(j)}{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/trans/new_code_testing/outputs/{str(j)}{str(i)}.parquet")
        sas[f'{str(j)}{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/trans/{str(j)}{str(i)}.parquet")
        a=tcs[f'{str(j)}{str(i)}'].count()
        b=sas[f'{str(j)}{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(f'{str(j)}{str(i)}',"counts :","new :", tcs[f'{str(j)}{str(i)}'].count(), "prev :", sas[f'{str(j)}{str(i)}'].count(),"% diff", c)) ###Record count##
        
check(202208,202229)
check(202233,202242)
check(202244,202252)
check(202301,202306)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">bas_202208 counts : new : 6210186 prev : 6210186 % diff 100.0
# bas_202209 counts : new : 6364396 prev : 6364396 % diff 100.0
# bas_202210 counts : new : 6222384 prev : 6222384 % diff 100.0
# bas_202211 counts : new : 6164582 prev : 6164582 % diff 100.0
# bas_202212 counts : new : 6303380 prev : 6303380 % diff 100.0
# bas_202213 counts : new : 6199219 prev : 6199219 % diff 100.0
# bas_202214 counts : new : 6397365 prev : 6397365 % diff 100.0
# bas_202215 counts : new : 6936516 prev : 6936516 % diff 100.0
# bas_202216 counts : new : 6302839 prev : 6302839 % diff 100.0
# bas_202217 counts : new : 6574698 prev : 6574698 % diff 100.0
# ...

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["card","hhld","customer","client_caract_mkt","customer_purge","clientrole"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/crm/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/crm/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
        
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["card","hhld","product","customer","store","store_extended","card_history","prod_history","prod_wk_history","sales_summary"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/ref/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
tcs1={}
sas={}
sas1={}
tcs_={}
sas_={}
diftcs={}
difsas={}
from  pyspark import pandas
tables = ["card","hhld","card_master","hhld_master","product","product_master","customer","store","store_master"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/prep/operations/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/prep/operations/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
        
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["status_log"]
def check():
    for i in tables:
        tcs[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/updatelog/build/{i}.parquet")
        sas[f'{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/updatelog/{i}.parquet")
        a=tcs[f'{str(i)}'].count()
        b=sas[f'{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(i,"counts :","new :", tcs[f'{str(i)}'].count(), "prev :", sas[f'{str(i)}'].count(),"% diff", c)) ###Record count##
check()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import *
import pandas as pd
import os
from pyspark.sql import SparkSession

tcs={}
sas={}
tcs_={}
sas_={}
diftcs={}
difsas={}
tables = ["bas_","bas_ex_","itm_","itm_ex_"]
def check(aa,bb):
  for j in tables:
    for i in range(aa,bb+1):
        tcs[f'{str(j)}{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/trans/build/{str(j)}{str(i)}.parquet")
        sas[f'{str(j)}{str(i)}'] = spark.read.parquet(f"/mnt/cis2-casino-niq/onboarding/pdl/trans/{str(j)}{str(i)}.parquet")
        a=tcs[f'{str(j)}{str(i)}'].count()
        b=sas[f'{str(j)}{str(i)}'].count()
        c=(a/b)*100
        # diff =spark.tcs[f'{str(i)}'].div(sas[f'{str(i)}'])*100
        display(print(f'{str(j)}{str(i)}',"counts :","new :", tcs[f'{str(j)}{str(i)}'].count(), "prev :", sas[f'{str(j)}{str(i)}'].count(),"% diff", c)) ###Record count##
        
check(202008,202053)
check(202101,202152)
check(202201,202252)
check(202301,202305)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# check(202301,202304)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
